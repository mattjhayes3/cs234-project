# %%
# !conda install aiohttp -y
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !git pull --rebase
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - aiohttp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following packages will be UPDATED:
#
#   aiohttp                             3.9.1-py310h2372a71_0 --> 3.9.5-py310h2372a71_0
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4ab18f5_0
#
#
#
# ...

# %%
# !python reward_modeling.py \
#     --model_name_or_path=gpt2 \
#     --output_dir="models/2c6-reward" \
#     --dataset="pref_pairs_16_token.csv" \
#     --per_device_train_batch_size=256 \
#     --per_device_eval_batch_size=256 \
#     --num_train_epochs=3 \
#     --gradient_accumulation_steps=1 \
#     --gradient_checkpointing=True \
#     --learning_rate=1.41e-5 \
#     --report_to="wandb" \
#     --remove_unused_columns=False \
#     --optim="adamw_torch" \
#     --logging_steps=10 \
#     --evaluation_strategy="steps" \
#     --eval_steps=100 \
#     --save_steps=100 \
#     --max_length=25 \
#     --load_best_model_at_end=True \
#     --save_total_limit=3 \
#     --lr_scheduler_type="constant_with_warmup" \
#     --warmup_steps=100

# %%
# !python reward_modeling.py \
#     --model_name_or_path=openai-community/gpt2-medium \
#     --output_dir="models/2c2-reward-medium" \
#     --dataset="pref_pairs_16_token_2_choose_2.csv" \
#     --per_device_train_batch_size=256 \
#     --per_device_eval_batch_size=256 \
#     --num_train_epochs=3 \
#     --gradient_accumulation_steps=1 \
#     --gradient_checkpointing=True \
#     --learning_rate=1.41e-5 \
#     --report_to="wandb" \
#     --remove_unused_columns=False \
#     --optim="adamw_torch" \
#     --logging_steps=5 \
#     --evaluation_strategy="steps" \
#     --eval_steps=20 \
#     --save_steps=20 \
#     --max_length=25 \
#     --load_best_model_at_end=True \
#     --save_total_limit=2 \
#     --lr_scheduler_type="constant_with_warmup" \
#     --warmup_steps=20

# %%
# !python ppo.py --exp_name=2c6-reward-roberta16-256_0_2 --reward_model=./models/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.2

# %%
# !python ppo.py --exp_name=2c6-reward-roberta16-256_0_05 --reward_model=./models/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.05

# %%
# !python ppo.py --exp_name=2c2-reward-medium-256_0_2-2c2 --reward_model=sentiment-analysis:DownwardSpiral33/2c2-reward-medium --normalize_scores=True --log_with=wandb --init_kl_coef=0.2
# Out:
# 2024-06-07 20:50:29.869802: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 20:50:29.869922: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 20:50:29.994467: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=2c2-reward-medium-256_0_05-2c2 --reward_model=sentiment-analysis:DownwardSpiral33/2c2-reward-medium --normalize_scores=True --log_with=wandb --init_kl_coef=0.05
# Out:
# 2024-06-07 21:46:01.863720: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 21:46:01.863778: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 21:46:01.865313: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
