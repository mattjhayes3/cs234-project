# %%
# !conda install aiohttp -y
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !git pull --rebase
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - aiohttp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following packages will be UPDATED:
#
#   aiohttp                             3.9.1-py310h2372a71_0 --> 3.9.5-py310h2372a71_0
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4ab18f5_0
#
#
#
# ...

# %%
# !python ppo.py --exp_name=ppo-4c2-reward-extratrain-256_0_05 --concat --reward_model=sentiment-analysis:DownwardSpiral33/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.05
# Out:
# 2024-06-08 02:51:18.046990: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 02:51:18.047088: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 02:51:18.156646: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=ppo-4c2-reward-extratrain-256_0_2 --concat --reward_model=sentiment-analysis:DownwardSpiral33/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.2
# Out:
# 2024-06-08 04:28:29.779926: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 04:28:29.779986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 04:28:29.781667: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=ppo-4c2-reward-extratrain-256_0_02 --reward_model=sentiment-analysis:DownwardSpiral33/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.02
# Out:
# 2024-06-08 06:04:39.238356: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 06:04:39.238424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 06:04:39.239956: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=ppo-4c2-reward-extratrain-256_0_5 --reward_model=sentiment-analysis:DownwardSpiral33/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.5
# Out:
# 2024-06-08 06:57:06.846163: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 06:57:06.846236: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 06:57:06.847823: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
