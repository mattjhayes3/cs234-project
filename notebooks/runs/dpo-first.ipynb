# %%
# !conda install -y gdown
# print('hi')
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# fatal: destination path 'cs234-project' already exists and is not an empty directory.
# /kaggle/working/cs234-project/cs234-project
# ...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# mkdir: cannot create directory 'results': File exists
# ...
#   Cloning https://github.com/mattjhayes3/trl.git to /tmp/pip-req-build-tjd_kdyu
#   Running command git clone --filter=blob:none --quiet https://github.com/mattjhayes3/trl.git /tmp/pip-req-build-tjd_kdyu
# ...

# %%
# !git pull --rebase && python dpo.py  --output_dir=test_dpo_0_2  --beta=0.2 --dataset_name=DownwardSpiral33/gpt2-imdb-16-token-pref-pairs     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128     --learning_rate 1e-3     --gradient_accumulation_steps 1     --logging_steps 10     --eval_steps 250     --warmup_steps 150     --report_to wandb     --logging_first_step --no_remove_unused_columns --save_total_limit=2 --load_best_model_at_end=True --evaluation_strategy='steps'
# Out:
# Already up to date.
# Current branch main is up to date.
# 2024-05-22 23:34:09.037264: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 23:34:09.037321: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 23:34:09.038966: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100%|█████████████████████████████| 577/577 [00:00<00:00, 3.06MB/s]
# pytorch_model.bin: 100%|██████████████████████| 548M/548M [00:01<00:00, 322MB/s]
# ...

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_2-2024.05.22.23.34
# Out:
# 2024-05-23 00:51:59.869625: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 00:51:59.869695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 00:51:59.871266: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on main: 871b18e dpo

# %%
# !git pull --rebase && python dpo.py  --output_dir=test_dpo_0_2_lr1e_5  --beta=0.2 --dataset_name=DownwardSpiral33/gpt2-imdb-16-token-pref-pairs     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128     --learning_rate 1e-5     --gradient_accumulation_steps 1      --eval_steps 500     --warmup_steps 150     --report_to wandb     --logging_first_step --logging_steps 10   --no_remove_unused_columns --save_total_limit=2 --load_best_model_at_end=True --evaluation_strategy='steps' --lr_scheduler_type=constant_with_warmup
# Out:
# Already up to date.
# Current branch main is up to date.
# 2024-05-23 01:15:13.048029: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 01:15:13.048086: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 01:15:13.049615: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %ls
# Out:
# '=0.3.0'    __init__.py         results/                                trl/
# '=0.5.7'    dpo.py              test_dpo_0_2-2024.05.22.23.34/          wandb/
# '=1.17.0'   gen_pref_pairs.py   test_dpo_0_2_lr1e_5-2024.05.23.01.05/
# '=1.4.0'    ppo.py              test_dpo_0_2_lr1e_5-2024.05.23.01.15/

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_2_lr1e_5-2024.05.23.01.15
# Out:
# 2024-05-23 02:27:12.847748: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 02:27:12.847822: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 02:27:12.849298: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cat trl/trainer/dpo_config.py
# Out:
# cat: trl/trainer/dpo_config.py: No such file or directory

# %%
# !git stash && git pull --rebase && cd trl && git pull --rebase && cd .. && python dpo.py  --output_dir=test_dpo_0_2_lr2e_6  --beta=0.2 --dataset_name=DownwardSpiral33/gpt2-imdb-16-token-pref-pairs     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128     --learning_rate 2e-6     --gradient_accumulation_steps 1  --warmup_steps 150     --report_to wandb     --logging_first_step --logging_steps 10   --no_remove_unused_columns --save_total_limit=4 --load_best_model_at_end=True --evaluation_strategy='epoch' --lr_scheduler_type=constant_with_warmup --save_strategy='epoch'
# Out:
# No local changes to save
# Already up to date.
# Current branch main is up to date.
# Already up to date.
# Current branch main is up to date.
# 2024-05-23 03:16:34.901075: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 03:16:34.901138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 03:16:34.902893: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd /kaggle/working/cs234-project/
# Out:
# /kaggle/working/cs234-project

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_2_lr2e_6-2024.05.23.03.16/checkpoint-3327
# Out:
# 2024-05-23 04:26:50.546753: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 04:26:50.546826: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 04:26:50.548659: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_2_lr2e_6-2024.05.23.03.16/checkpoint-2218
# Out:
# 2024-05-23 04:31:36.516569: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 04:31:36.516629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 04:31:36.518371: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_2_lr2e_6-2024.05.23.03.16/checkpoint-1109
# Out:
# 2024-05-23 04:41:15.107691: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 04:41:15.107759: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 04:41:15.109274: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !git stash && git pull --rebase && cd trl && git pull --rebase && cd .. && python dpo.py  --output_dir=test_dpo_0_3_lr2e_6  --beta=0.3 --dataset_name=DownwardSpiral33/gpt2-imdb-16-token-pref-pairs     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128     --learning_rate 2e-6     --gradient_accumulation_steps 1  --warmup_steps 150     --report_to wandb     --logging_first_step --logging_steps 10   --no_remove_unused_columns --save_total_limit=4 --load_best_model_at_end=True --evaluation_strategy='epoch' --lr_scheduler_type=constant_with_warmup --save_strategy='epoch'
# Out:
# Saved working directory and index state WIP on main: 134849d dpo
# Already up to date.
# Current branch main is up to date.
# Already up to date.
# Current branch main is up to date.
# 2024-05-23 05:02:00.391034: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 05:02:00.391098: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 05:02:00.392669: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %ls
# Out:
# '=0.3.0'             test_dpo_0_2-2024.05.22.23.34/
# '=0.5.7'             test_dpo_0_2_lr1e_5-2024.05.23.01.05/
# '=1.17.0'            test_dpo_0_2_lr1e_5-2024.05.23.01.15/
# '=1.4.0'             test_dpo_0_2_lr1e_5-2024.05.23.02.43/
#  __init__.py         test_dpo_0_2_lr2e_6-2024.05.23.02.58/
#  cs234-project/      test_dpo_0_2_lr2e_6-2024.05.23.03.16/
#  dpo.py              test_dpo_0_3_lr2e_6-2024.05.23.05.02/
#  gen_pref_pairs.py   trl/
#  ppo.py              wandb/
#  results/

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_3_lr2e_6-2024.05.23.05.02/checkpoint-3327
# Out:
# 2024-05-23 06:21:00.071777: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 06:21:00.071853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 06:21:00.073306: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_3_lr2e_6-2024.05.23.05.02/checkpoint-2218
# Out:
# 2024-05-23 06:33:31.470091: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 06:33:31.470156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 06:33:31.471556: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=eval --log_with=wandb --eval_model=./test_dpo_0_3_lr2e_6-2024.05.23.05.02/checkpoint-1109
# Out:
# 2024-05-23 06:42:00.680986: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 06:42:00.681050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 06:42:00.682701: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
