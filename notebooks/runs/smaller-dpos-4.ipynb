# %%
# !conda install -y gdown
# print('hi')
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Cloning into 'cs234-project'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 171 (delta 72), reused 142 (delta 45), pack-reused 0
# Receiving objects: 100% (171/171), 36.81 MiB | 9.79 MiB/s, done.
# Resolving deltas: 100% (72/72), done.
# Updating files: 100% (63/63), done.
# Encountered 8 file(s) that should have been pointers, but weren't:
# 	gpt2-imdb-16-token-pref-pairs-2-choose-2_tokenized/train/data-00000-of-00001.arrow
# 	gpt2-imdb-16-token-pref-pairs-3-choose-2-div-3_tokenized/train/data-00000-of-00001.arrow
# 	gpt2-imdb-16-token-pref-pairs-3-distinct-pairs_tokenized/train/data-00000-of-00001.arrow
# 	gpt2-imdb-16-token-pref-pairs-4-choose-2-div-6_tokenized/train/cache-13e54457644d5a49.arrow
# 	gpt2-imdb-16-token-pref-pairs-4-choose-2-div-6_tokenized/train/cache-33e29b9c6ccd8398.arrow
# ...

# %%
! python dpo.py  --output_dir=dpo_6c2_div6_actual-0_05  --beta=0.05 --dataset_name=/kaggle/working/cs234-project/gpt2-imdb-16-token-pref-pairs-4-choose-2-div-6_tokenized     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128  --per_device_eval_batch_size 128     --learning_rate 2e-6     --gradient_accumulation_steps 1  --warmup_steps 150     --report_to wandb     --logging_first_step --logging_strategy='steps' --logging_steps 50  --eval_steps=200 --no_remove_unused_columns --save_total_limit=4 --evaluation_strategy='steps' --lr_scheduler_type=constant_with_warmup --save_strategy='epoch' --num_train_epochs=4
# Out:
# 2024-05-30 10:52:43.078852: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 10:52:43.078965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 10:52:43.207834: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100%|█████████████████████████████| 577/577 [00:00<00:00, 3.60MB/s]
# pytorch_model.bin: 100%|█████████████████████| 548M/548M [00:13<00:00, 41.8MB/s]
# ...

# %%
# !python ppo.py --exp_name=eval --eval_model=./dpo_6c2_div6_actual-0_05-2024.05.30.10.52/checkpoint-740
# !python ppo.py --exp_name=eval --eval_model=./dpo_6c2_div6_actual-0_05-2024.05.30.10.52/checkpoint-555
# !python ppo.py --exp_name=eval --eval_model=./dpo_6c2_div6_actual-0_05-2024.05.30.10.52/checkpoint-370
# !python ppo.py --exp_name=eval --eval_model=./dpo_6c2_div6_actual-0_1-2024.05.30.07.06/checkpoint-185
# Out:
# 2024-05-30 11:14:53.421431: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 11:14:53.421502: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 11:14:53.422991: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
! python dpo.py  --output_dir=dpo_2c2_div6-0_05  --beta=0.05 --dataset_name=/kaggle/working/cs234-project/gpt2-imdb-16-token-pref-pairs-2-choose-2_tokenized     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128  --per_device_eval_batch_size 128     --learning_rate 2e-6     --gradient_accumulation_steps 1  --warmup_steps 150     --report_to wandb     --logging_first_step --logging_strategy='steps' --logging_steps 50  --eval_steps=200 --no_remove_unused_columns --save_total_limit=4 --evaluation_strategy='steps' --lr_scheduler_type=constant_with_warmup --save_strategy='epoch' --num_train_epochs=4
# Out:
# 2024-05-30 11:41:53.732910: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 11:41:53.732970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 11:41:53.734631: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
# ...

# %%
# !python ppo.py --exp_name=eval --eval_model=./dpo_2c2_div6-0_05-2024.05.30.11.41/checkpoint-740
# !python ppo.py --exp_name=eval --eval_model=./dpo_2c2_div6-0_05-2024.05.30.11.41/checkpoint-555
# !python ppo.py --exp_name=eval --eval_model=./dpo_2c2_div6-0_05-2024.05.30.11.41/checkpoint-370
# !python ppo.py --exp_name=eval --eval_model=./dpo_2c2_div6-0_05-2024.05.30.11.41/checkpoint-185
# Out:
# 2024-05-30 12:01:52.039558: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 12:01:52.039620: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 12:01:52.041321: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !git rm --cached -r .
# !git reset --hard
# !git rm .gitattributes
# !git reset .
# !git checkout .
# Out:
# rm '.gitattributes'
# rm '.gitignore'
# rm '.gitmodules'
# rm '__init__.py'
# rm 'dpo.py'
# rm 'gen_pref_pairs.py'
# rm 'gpt2-imdb-16-token-pref-pairs-2-choose-2_tokenized/dataset_dict.json'
# rm 'gpt2-imdb-16-token-pref-pairs-2-choose-2_tokenized/train/data-00000-of-00001.arrow'
# rm 'gpt2-imdb-16-token-pref-pairs-2-choose-2_tokenized/train/dataset_info.json'
# rm 'gpt2-imdb-16-token-pref-pairs-2-choose-2_tokenized/train/state.json'
# rm 'gpt2-imdb-16-token-pref-pairs-3-choose-2-div-3_tokenized/dataset_dict.json'
# rm 'gpt2-imdb-16-token-pref-pairs-3-choose-2-div-3_tokenized/train/data-00000-of-00001.arrow'
# rm 'gpt2-imdb-16-token-pref-pairs-3-choose-2-div-3_tokenized/train/dataset_info.json'
# rm 'gpt2-imdb-16-token-pref-pairs-3-choose-2-div-3_tokenized/train/state.json'
# rm 'gpt2-imdb-16-token-pref-pairs-3-distinct-pairs_tokenized/dataset_dict.json'
# rm 'gpt2-imdb-16-token-pref-pairs-3-distinct-pairs_tokenized/train/data-00000-of-00001.arrow'
# ...

# %%
# !git stash && git pull --rebase
# Out:
# No local changes to save
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), 281 bytes | 281.00 KiB/s, done.
# From https://github.com/mattjhayes3/cs234-project
#    9701a52..947f719  main       -> origin/main
# Updating 9701a52..947f719
# Fast-forward
#  ppo.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Current branch main is up to date.
