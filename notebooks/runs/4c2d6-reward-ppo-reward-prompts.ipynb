# %%
# !conda install aiohttp -y
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !git pull --rebase
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - aiohttp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     certifi-2024.6.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.6 MB
#
# The following packages will be UPDATED:
#
#   aiohttp                             3.9.1-py310h2372a71_0 --> 3.9.5-py310h2372a71_0
# ...

# %%
# !python ppo.py --exp_name=4c2-d6-reward-256_0_2-rewardprompts --reward_model=sentiment-analysis:DownwardSpiral33/2c6-d6-reward --normalize_scores=True --init_kl_coef=0.2 --query_dataset=./data/pref_pairs_16_token_4_choose_2_div_6_promptonly.csv
# Out:
# 2024-06-10 21:56:22.248790: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 21:56:22.248933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 21:56:22.380816: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=4c2-d6-reward-256_0_05-rewardprompts --reward_model=sentiment-analysis:DownwardSpiral33/2c6-d6-reward --normalize_scores=True --init_kl_coef=0.05 --query_dataset=./data/pref_pairs_16_token_4_choose_2_div_6_promptonly.csv
# Out:
# 2024-06-10 22:08:07.361196: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 22:08:07.361259: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 22:08:07.362918: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=4c2-d6-reward-256_0_022-rewardprompts --reward_model=sentiment-analysis:DownwardSpiral33/2c6-d6-reward --normalize_scores=True --init_kl_coef=0.022 --query_dataset=./data/pref_pairs_16_token_4_choose_2_div_6_promptonly.csv
# Out:
# 2024-06-10 22:19:29.414876: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 22:19:29.414938: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 22:19:29.416374: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ppo.py --exp_name=4c2-d6-reward-256_0_035-rewardprompts --reward_model=sentiment-analysis:DownwardSpiral33/2c6-d6-reward --normalize_scores=True --init_kl_coef=0.035 --query_dataset=./data/pref_pairs_16_token_4_choose_2_div_6_promptonly.csv
# Out:
# 2024-06-10 22:30:52.195529: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 22:30:52.195598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 22:30:52.197115: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
