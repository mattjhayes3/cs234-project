# %%
# !conda install aiohttp -y
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !git pull --rebase
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - aiohttp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following packages will be UPDATED:
#
#   aiohttp                             3.9.1-py310h2372a71_0 --> 3.9.5-py310h2372a71_0
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4ab18f5_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
# openssl-3.3.1        | 2.8 MB    | ##5                                   |   7%
# aiohttp-3.9.5        | 682 KB    | ###4                                  |   9%
# aiohttp-3.9.5        | 682 KB    | ##################################### | 100%
#
#
# done
# done
# done
# Cloning into 'cs234-project'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 316 (delta 57), reused 70 (delta 32), pack-reused 220
# Receiving objects: 100% (316/316), 66.92 MiB | 21.78 MiB/s, done.
# Resolving deltas: 100% (164/164), done.
# Updating files: 100% (129/129), done.
# /kaggle/working/cs234-project
# Already up to date.
# Current branch main is up to date.
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.3.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Collecting git+https://github.com/mattjhayes3/trl.git
#   Cloning https://github.com/mattjhayes3/trl.git to /tmp/pip-req-build-x2hhbqvs
#   Running command git clone --filter=blob:none --quiet https://github.com/mattjhayes3/trl.git /tmp/pip-req-build-x2hhbqvs
#   Resolved https://github.com/mattjhayes3/trl.git to commit fce91ab1b2401a45a767d7ca6eeb940790cdd954
# done
# done
# done
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (4.41.2)
# Requirement already satisfied: numpy>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (1.26.4)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (0.30.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (2.19.2)
# Requirement already satisfied: tyro>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (0.8.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (4.66.4)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (1.7.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->trl==0.8.7.dev0) (5.9.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (2.2.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.9.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->trl==0.8.7.dev0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl==0.8.7.dev0) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2023.4)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl==0.8.7.dev0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.8.7.dev0) (1.16.0)
# Building wheels for collected packages: trl
# done
#   Created wheel for trl: filename=trl-0.8.7.dev0-py3-none-any.whl size=209807 sha256=6c45539c039be92ce7aa821c377771b7ceb6e41db53551e2e576a92481190612
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wy0ctpup/wheels/b5/f5/74/f982e27bdb1c23b205f8bfcaaed174cf3d2c06bd1a5f5926cc
# Successfully built trl
# Installing collected packages: trl
# Successfully installed trl-0.8.7.dev0

# %%
# !python reward_modeling.py \
#     --model_name_or_path=gpt2 \
#     --output_dir="models/2c6-reward" \
#     --dataset="pref_pairs_16_token.csv" \
#     --per_device_train_batch_size=256 \
#     --per_device_eval_batch_size=256 \
#     --num_train_epochs=3 \
#     --gradient_accumulation_steps=1 \
#     --gradient_checkpointing=True \
#     --learning_rate=1.41e-5 \
#     --report_to="wandb" \
#     --remove_unused_columns=False \
#     --optim="adamw_torch" \
#     --logging_steps=10 \
#     --evaluation_strategy="steps" \
#     --eval_steps=100 \
#     --save_steps=100 \
#     --max_length=25 \
#     --load_best_model_at_end=True \
#     --save_total_limit=3 \
#     --lr_scheduler_type="constant_with_warmup" \
#     --warmup_steps=100

# %%
# !python ppo.py --exp_name=2c6-reward-roberta16-256_0_2 --reward_model=sentiment-analysis:DownwardSpiral33/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.2
# Out:
# 2024-06-07 21:02:13.612031: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 21:02:13.612153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 21:02:13.730759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# PPOConfig: PPOConfig(exp_name='2c6-reward-roberta16-256_0_2', sgd=False, ac2=False, normalize_scores=True, dry_run=False, eval_model=None, seed=0, log_with='wandb', task_name=None, model_name='lvwerra/gpt2-imdb', query_dataset='imdb', reward_model='sentiment-analysis:DownwardSpiral33/2c6-reward', remove_unused_columns=True, tracker_kwargs={'wandb': {'name': '2c6-reward-roberta16-256_0_2-2024.06.07.21.02'}}, accelerator_kwargs={}, project_kwargs={}, tracker_project_name='cs234', push_to_hub_if_best_kwargs={}, steps=20000, learning_rate=1.41e-05, adap_kl_ctrl=False, init_kl_coef=0.2, kl_penalty='kl', target=6, horizon=10000, gamma=1, lam=0.95, cliprange=0.2, cliprange_value=0.2, vf_coef=0.1, batch_size=256, forward_batch_size=None, mini_batch_size=256, gradient_accumulation_steps=1, world_size=None, ppo_epochs=4, max_grad_norm=None, optimize_cuda_cache=None, optimize_device_cache=False, early_stopping=False, target_kl=1, compare_steps=1, ratio_threshold=10.0, use_score_scaling=False, use_score_norm=False, score_clip=None, whiten_rewards=False, is_encoder_decoder=None, is_peft_model=None, backward_batch_size=256, global_backward_batch_size=None, global_batch_size=None)
# tokenizer_config.json: 100%|██████████████████| 17.0/17.0 [00:00<00:00, 115kB/s]
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100%|█████████████████████████████| 577/577 [00:00<00:00, 4.56MB/s]
# vocab.json: 100%|████████████████████████████| 899k/899k [00:00<00:00, 4.79MB/s]
# merges.txt: 100%|████████████████████████████| 456k/456k [00:00<00:00, 29.8MB/s]
# special_tokens_map.json: 100%|████████████████| 90.0/90.0 [00:00<00:00, 598kB/s]
# Downloading readme: 100%|██████████████████| 7.81k/7.81k [00:00<00:00, 23.9MB/s]
# Downloading data: 100%|████████████████████| 21.0M/21.0M [00:00<00:00, 61.3MB/s]
# Downloading data: 100%|████████████████████| 20.5M/20.5M [00:00<00:00, 65.6MB/s]
# Downloading data: 100%|████████████████████| 42.0M/42.0M [00:00<00:00, 96.7MB/s]
# Generating train split: 100%|██| 25000/25000 [00:00<00:00, 137394.91 examples/s]
# Generating test split: 100%|███| 25000/25000 [00:00<00:00, 191519.68 examples/s]
# Generating unsupervised split: 100%|█| 50000/50000 [00:00<00:00, 186068.33 examp
# Filter: 100%|██████████████████| 25000/25000 [00:00<00:00, 164092.29 examples/s]
# Map:   0%|                                     | 0/24895 [00:00<?, ? examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors
# Map: 100%|████████████████████████| 24895/24895 [00:28<00:00, 879.91 examples/s]
# load ref model lvwerra/gpt2-imdb
# pytorch_model.bin: 100%|██████████████████████| 548M/548M [00:02<00:00, 249MB/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# load train model lvwerra/gpt2-imdb
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240607_210306-21ime7if
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2c6-reward-roberta16-256_0_2-2024.06.07.21.02
# wandb: ⭐️ View project at https://wandb.ai/mhayes/cs234
# wandb: 🚀 View run at https://wandb.ai/mhayes/cs234/runs/21ime7if
# device cuda
# device 0
# Load reward model DownwardSpiral33/2c6-reward
# config.json: 100%|█████████████████████████| 1.02k/1.02k [00:00<00:00, 3.48MB/s]
# model.safetensors: 100%|██████████████████████| 498M/498M [00:01<00:00, 252MB/s]
# tokenizer_config.json: 100%|███████████████████| 476/476 [00:00<00:00, 1.59MB/s]
# vocab.json: 100%|████████████████████████████| 798k/798k [00:00<00:00, 4.15MB/s]
# merges.txt: 100%|████████████████████████████| 456k/456k [00:00<00:00, 85.1MB/s]
# tokenizer.json: 100%|██████████████████████| 2.11M/2.11M [00:00<00:00, 25.9MB/s]
# special_tokens_map.json: 100%|██████████████████| 131/131 [00:00<00:00, 491kB/s]
#   0%|                                                    | 0/97 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#   5%|██▎                                         | 5/97 [02:27<45:08, 29.44s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|███████████████████████████████████████████| 97/97 [48:21<00:00, 29.92s/it]
# model.safetensors: 100%|█████████████████████| 498M/498M [00:13<00:00, 36.2MB/s]
# Training done!  Start eval
# eval batch size 256
# Filter: 100%|████████████████████| 2500/2500 [00:00<00:00, 126328.37 examples/s]
# Map:   3%|▉                           | 79/2487 [00:00<00:03, 774.53 examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1300 > 1024). Running this sequence through the model will result in indexing errors
# Map: 100%|██████████████████████████| 2487/2487 [00:02<00:00, 855.75 examples/s]
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:35, 27.00s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:53<03:06, 26.63s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:19<02:39, 26.61s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:46<02:12, 26.51s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:12<01:46, 26.51s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:39<01:19, 26.52s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:06<00:53, 26.62s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:33<00:26, 26.70s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:00<00:00, 26.70s/it]
# mean test reward 0.7483723377595324 +/- 0.006972652545486084 from 0.41470273516380807 +/- 0.007657512487143422
# median test reward 0.936430960893631 from 0.3036431819200516
# mean KL 0.6016765150836565 +/- 0.06478577501708517 full 2.7473096491561995 +/- 0.016414826729674415
# median KL 0.8628312349319458 full 2.6380754709243774
# 2c6-reward-roberta16-256_0_2-2024.06.07.21.02,0.2,epoch 1,0.7483723377595324,0.006972652545486084,2.7473096491561995,0.016414826729674415,15.61935763888889

# %%
# !python ppo.py --exp_name=2c6-reward-roberta16-256_0_05 --reward_model=sentiment-analysis:DownwardSpiral33/2c6-reward --normalize_scores=True --log_with=wandb --init_kl_coef=0.05
# Out:
# 2024-06-07 21:56:25.557766: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 21:56:25.557833: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 21:56:25.559470: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# PPOConfig: PPOConfig(exp_name='2c6-reward-roberta16-256_0_05', sgd=False, ac2=False, normalize_scores=True, dry_run=False, eval_model=None, seed=0, log_with='wandb', task_name=None, model_name='lvwerra/gpt2-imdb', query_dataset='imdb', reward_model='sentiment-analysis:DownwardSpiral33/2c6-reward', remove_unused_columns=True, tracker_kwargs={'wandb': {'name': '2c6-reward-roberta16-256_0_05-2024.06.07.21.56'}}, accelerator_kwargs={}, project_kwargs={}, tracker_project_name='cs234', push_to_hub_if_best_kwargs={}, steps=20000, learning_rate=1.41e-05, adap_kl_ctrl=False, init_kl_coef=0.05, kl_penalty='kl', target=6, horizon=10000, gamma=1, lam=0.95, cliprange=0.2, cliprange_value=0.2, vf_coef=0.1, batch_size=256, forward_batch_size=None, mini_batch_size=256, gradient_accumulation_steps=1, world_size=None, ppo_epochs=4, max_grad_norm=None, optimize_cuda_cache=None, optimize_device_cache=False, early_stopping=False, target_kl=1, compare_steps=1, ratio_threshold=10.0, use_score_scaling=False, use_score_norm=False, score_clip=None, whiten_rewards=False, is_encoder_decoder=None, is_peft_model=None, backward_batch_size=256, global_backward_batch_size=None, global_batch_size=None)
# load ref model lvwerra/gpt2-imdb
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# load train model lvwerra/gpt2-imdb
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240607_215636-ad0ba9h8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2c6-reward-roberta16-256_0_05-2024.06.07.21.56
# wandb: ⭐️ View project at https://wandb.ai/mhayes/cs234
# wandb: 🚀 View run at https://wandb.ai/mhayes/cs234/runs/ad0ba9h8
# device cuda
# device 0
# Load reward model DownwardSpiral33/2c6-reward
#   0%|                                                    | 0/97 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#   5%|██▎                                         | 5/97 [02:31<46:52, 30.57s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|███████████████████████████████████████████| 97/97 [49:15<00:00, 30.47s/it]
# model.safetensors: 100%|█████████████████████| 498M/498M [00:12<00:00, 40.7MB/s]
# Training done!  Start eval
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:34, 26.83s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:52<03:02, 26.14s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:19<02:38, 26.41s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:45<02:12, 26.51s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:12<01:46, 26.61s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:39<01:20, 26.72s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:06<00:53, 26.73s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:32<00:26, 26.55s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [03:58<00:00, 26.52s/it]
# mean test reward 0.9106861881313838 +/- 0.004619526249286293 from 0.41470273516380807 +/- 0.007657512487143422
# median test reward 0.9915905296802521 from 0.3036431819200516
# mean KL 2.8732400399943194 +/- 0.14540367012952507 full 9.891390457231966 +/- 0.053622446198420964
# median KL 3.9444141387939453 full 9.572208404541016
# 2c6-reward-roberta16-256_0_05-2024.06.07.21.56,0.05,epoch 1,0.9106861881313838,0.004619526249286293,9.891390457231966,0.053622446198420964,15.667100694444445
