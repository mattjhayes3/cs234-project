# %%
# !conda install aiohttp -y
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !git pull --rebase
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - aiohttp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     openssl-3.3.1              |       h4ab18f5_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following packages will be UPDATED:
#
#   aiohttp                             3.9.1-py310h2372a71_0 --> 3.9.5-py310h2372a71_0
#   openssl                                  3.3.0-h4ab18f5_3 --> 3.3.1-h4ab18f5_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
# aiohttp-3.9.5        | 682 KB    |                                       |   0%
# aiohttp-3.9.5        | 682 KB    | ##################################### | 100%
#
#
# done
# done
# done
# Cloning into 'cs234-project'...
# remote: Enumerating objects: 304, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 304 (delta 51), reused 61 (delta 29), pack-reused 220
# Receiving objects: 100% (304/304), 60.49 MiB | 13.94 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# Updating files: 100% (127/127), done.
# /kaggle/working/cs234-project
# Already up to date.
# Current branch main is up to date.
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.3.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Collecting git+https://github.com/mattjhayes3/trl.git
#   Cloning https://github.com/mattjhayes3/trl.git to /tmp/pip-req-build-3903by1v
#   Running command git clone --filter=blob:none --quiet https://github.com/mattjhayes3/trl.git /tmp/pip-req-build-3903by1v
#   Resolved https://github.com/mattjhayes3/trl.git to commit fce91ab1b2401a45a767d7ca6eeb940790cdd954
# done
# done
# done
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (4.41.2)
# Requirement already satisfied: numpy>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (1.26.4)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (0.30.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (2.19.2)
# Requirement already satisfied: tyro>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (0.8.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (4.66.4)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (1.7.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->trl==0.8.7.dev0) (5.9.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (2.2.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.9.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->trl==0.8.7.dev0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl==0.8.7.dev0) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2023.4)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl==0.8.7.dev0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.8.7.dev0) (1.16.0)
# Building wheels for collected packages: trl
# done
#   Created wheel for trl: filename=trl-0.8.7.dev0-py3-none-any.whl size=209807 sha256=cc40d5c808b0a981315cfef5abcff481289ec82fcee9a688c5a77e38936cb134
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7e2s0n0h/wheels/b5/f5/74/f982e27bdb1c23b205f8bfcaaed174cf3d2c06bd1a5f5926cc
# Successfully built trl
# Installing collected packages: trl
# Successfully installed trl-0.8.7.dev0

# %%
# !python ppo.py --exp_name=roberta16-256_0_05-gamma --normalize_scores=True --log_with=wandb --init_kl_coef=0.05 --gamma=0.95
# Out:
# 2024-06-06 07:58:58.151931: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 07:58:58.152048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 07:58:58.279139: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# PPOConfig: PPOConfig(exp_name='roberta16-256_0_05-gamma', sgd=False, ac2=False, normalize_scores=True, dry_run=False, eval_model=None, seed=0, log_with='wandb', task_name=None, model_name='lvwerra/gpt2-imdb', query_dataset='imdb', reward_model='sentiment-analysis:siebert/sentiment-roberta-large-english', remove_unused_columns=True, tracker_kwargs={'wandb': {'name': 'roberta16-256_0_05-gamma-2024.06.06.07.59'}}, accelerator_kwargs={}, project_kwargs={}, tracker_project_name='cs234', push_to_hub_if_best_kwargs={}, steps=20000, learning_rate=1.41e-05, adap_kl_ctrl=False, init_kl_coef=0.05, kl_penalty='kl', target=6, horizon=10000, gamma=0.95, lam=0.95, cliprange=0.2, cliprange_value=0.2, vf_coef=0.1, batch_size=256, forward_batch_size=None, mini_batch_size=256, gradient_accumulation_steps=1, world_size=None, ppo_epochs=4, max_grad_norm=None, optimize_cuda_cache=None, optimize_device_cache=False, early_stopping=False, target_kl=1, compare_steps=1, ratio_threshold=10.0, use_score_scaling=False, use_score_norm=False, score_clip=None, whiten_rewards=False, is_encoder_decoder=None, is_peft_model=None, backward_batch_size=256, global_backward_batch_size=None, global_batch_size=None)
# tokenizer_config.json: 100%|██████████████████| 17.0/17.0 [00:00<00:00, 124kB/s]
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100%|█████████████████████████████| 577/577 [00:00<00:00, 4.18MB/s]
# vocab.json: 100%|████████████████████████████| 899k/899k [00:00<00:00, 1.32MB/s]
# merges.txt: 100%|█████████████████████████████| 456k/456k [00:00<00:00, 895kB/s]
# special_tokens_map.json: 100%|████████████████| 90.0/90.0 [00:00<00:00, 652kB/s]
# Downloading readme: 100%|██████████████████| 7.81k/7.81k [00:00<00:00, 21.6MB/s]
# Downloading data: 100%|████████████████████| 21.0M/21.0M [00:03<00:00, 6.25MB/s]
# Downloading data: 100%|████████████████████| 20.5M/20.5M [00:01<00:00, 14.1MB/s]
# Downloading data: 100%|████████████████████| 42.0M/42.0M [00:01<00:00, 41.0MB/s]
# Generating train split: 100%|██| 25000/25000 [00:00<00:00, 134776.15 examples/s]
# Generating test split: 100%|███| 25000/25000 [00:00<00:00, 186637.48 examples/s]
# Generating unsupervised split: 100%|█| 50000/50000 [00:00<00:00, 183674.23 examp
# Filter: 100%|██████████████████| 25000/25000 [00:00<00:00, 165595.83 examples/s]
# Map:   0%|                                     | 0/24895 [00:00<?, ? examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors
# Map: 100%|████████████████████████| 24895/24895 [00:28<00:00, 884.53 examples/s]
# load ref model lvwerra/gpt2-imdb
# pytorch_model.bin: 100%|█████████████████████| 548M/548M [00:25<00:00, 21.7MB/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# load train model lvwerra/gpt2-imdb
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240606_080029-ovlkq51b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run roberta16-256_0_05-gamma-2024.06.06.07.59
# wandb: ⭐️ View project at https://wandb.ai/mhayes/cs234
# wandb: 🚀 View run at https://wandb.ai/mhayes/cs234/runs/ovlkq51b
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# config.json: 100%|█████████████████████████████| 687/687 [00:00<00:00, 2.13MB/s]
# pytorch_model.bin: 100%|███████████████████| 1.42G/1.42G [01:08<00:00, 20.7MB/s]
# tokenizer_config.json: 100%|████████████████████| 256/256 [00:00<00:00, 856kB/s]
# vocab.json: 100%|████████████████████████████| 798k/798k [00:00<00:00, 1.19MB/s]
# merges.txt: 100%|█████████████████████████████| 456k/456k [00:00<00:00, 891kB/s]
# special_tokens_map.json: 100%|██████████████████| 150/150 [00:00<00:00, 485kB/s]
#   0%|                                                    | 0/97 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#   5%|██▎                                         | 5/97 [02:33<46:57, 30.62s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|███████████████████████████████████████████| 97/97 [47:45<00:00, 29.54s/it]
# model.safetensors: 100%|█████████████████████| 498M/498M [00:33<00:00, 14.8MB/s]
# Training done!  Start eval
# eval batch size 256
# Filter: 100%|████████████████████| 2500/2500 [00:00<00:00, 128985.66 examples/s]
# Map:   3%|▉                           | 81/2487 [00:00<00:03, 792.39 examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1300 > 1024). Running this sequence through the model will result in indexing errors
# Map: 100%|██████████████████████████| 2487/2487 [00:02<00:00, 870.43 examples/s]
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:24<03:18, 24.76s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:48<02:47, 23.97s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:12<02:24, 24.05s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:36<01:59, 23.92s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [01:59<01:35, 23.79s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:23<01:11, 23.91s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [02:46<00:47, 23.65s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:10<00:23, 23.63s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [03:35<00:00, 23.91s/it]
# mean test reward 0.8855598840508492 +/- 0.006513017628692393 from 0.4448849355636134 +/- 0.010244402740167219
# median test reward 0.9983990788459778 from 0.010086259339004755
# mean KL -1.4420814053155482 +/- 0.1494851982292489 full 18.126629722615082 +/- 0.07264026919305748
# median KL -1.1194713115692139 full 18.062637329101562
# roberta16-256_0_05-gamma-2024.06.06.07.59,0.05,epoch 1,0.8855598840508492,0.006513017628692393,18.126629722615082,0.07264026919305748,7.351128472222222

# %%
# !python ppo.py --exp_name=roberta16-256_0_2-gamma --normalize_scores=True --log_with=wandb --init_kl_coef=0.2 --gamma=0.95
# Out:
# 2024-06-06 08:54:22.606017: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 08:54:22.606082: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 08:54:22.607763: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# PPOConfig: PPOConfig(exp_name='roberta16-256_0_2-gamma', sgd=False, ac2=False, normalize_scores=True, dry_run=False, eval_model=None, seed=0, log_with='wandb', task_name=None, model_name='lvwerra/gpt2-imdb', query_dataset='imdb', reward_model='sentiment-analysis:siebert/sentiment-roberta-large-english', remove_unused_columns=True, tracker_kwargs={'wandb': {'name': 'roberta16-256_0_2-gamma-2024.06.06.08.54'}}, accelerator_kwargs={}, project_kwargs={}, tracker_project_name='cs234', push_to_hub_if_best_kwargs={}, steps=20000, learning_rate=1.41e-05, adap_kl_ctrl=False, init_kl_coef=0.2, kl_penalty='kl', target=6, horizon=10000, gamma=0.95, lam=0.95, cliprange=0.2, cliprange_value=0.2, vf_coef=0.1, batch_size=256, forward_batch_size=None, mini_batch_size=256, gradient_accumulation_steps=1, world_size=None, ppo_epochs=4, max_grad_norm=None, optimize_cuda_cache=None, optimize_device_cache=False, early_stopping=False, target_kl=1, compare_steps=1, ratio_threshold=10.0, use_score_scaling=False, use_score_norm=False, score_clip=None, whiten_rewards=False, is_encoder_decoder=None, is_peft_model=None, backward_batch_size=256, global_backward_batch_size=None, global_batch_size=None)
# load ref model lvwerra/gpt2-imdb
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# load train model lvwerra/gpt2-imdb
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240606_085438-djiuiqak
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run roberta16-256_0_2-gamma-2024.06.06.08.54
# wandb: ⭐️ View project at https://wandb.ai/mhayes/cs234
# wandb: 🚀 View run at https://wandb.ai/mhayes/cs234/runs/djiuiqak
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
#   0%|                                                    | 0/97 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#   5%|██▎                                         | 5/97 [02:31<46:33, 30.36s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|███████████████████████████████████████████| 97/97 [49:16<00:00, 30.48s/it]
# model.safetensors: 100%|█████████████████████| 498M/498M [00:35<00:00, 14.1MB/s]
# Training done!  Start eval
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:27<03:39, 27.46s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:54<03:09, 27.09s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:20<02:41, 26.86s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:47<02:13, 26.78s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:14<01:46, 26.71s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:40<01:19, 26.62s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:07<00:53, 26.68s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:33<00:26, 26.65s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:00<00:00, 26.75s/it]
# mean test reward 0.7069906045084685 +/- 0.009362169715827524 from 0.4373831782098705 +/- 0.010218943991290022
# median test reward 0.9973642826080322 from 0.009207388386130333
# mean KL 0.6795217363137959 +/- 0.04974129250469397 full 2.0597941090818495 +/- 0.0129063572005253
# median KL 0.7280322313308716 full 1.9752696752548218
# roberta16-256_0_2-gamma-2024.06.06.08.54,0.2,epoch 1,0.7069906045084685,0.009362169715827524,2.0597941090818495,0.0129063572005253,15.58203125

# %%
# !python ppo.py --exp_name=roberta16-256_0_5-gamma --normalize_scores=True --log_with=wandb --init_kl_coef=0.5 --gamma=0.95
# Out:
# 2024-06-06 09:49:12.343736: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 09:49:12.343791: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 09:49:12.345358: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# PPOConfig: PPOConfig(exp_name='roberta16-256_0_5-gamma', sgd=False, ac2=False, normalize_scores=True, dry_run=False, eval_model=None, seed=0, log_with='wandb', task_name=None, model_name='lvwerra/gpt2-imdb', query_dataset='imdb', reward_model='sentiment-analysis:siebert/sentiment-roberta-large-english', remove_unused_columns=True, tracker_kwargs={'wandb': {'name': 'roberta16-256_0_5-gamma-2024.06.06.09.49'}}, accelerator_kwargs={}, project_kwargs={}, tracker_project_name='cs234', push_to_hub_if_best_kwargs={}, steps=20000, learning_rate=1.41e-05, adap_kl_ctrl=False, init_kl_coef=0.5, kl_penalty='kl', target=6, horizon=10000, gamma=0.95, lam=0.95, cliprange=0.2, cliprange_value=0.2, vf_coef=0.1, batch_size=256, forward_batch_size=None, mini_batch_size=256, gradient_accumulation_steps=1, world_size=None, ppo_epochs=4, max_grad_norm=None, optimize_cuda_cache=None, optimize_device_cache=False, early_stopping=False, target_kl=1, compare_steps=1, ratio_threshold=10.0, use_score_scaling=False, use_score_norm=False, score_clip=None, whiten_rewards=False, is_encoder_decoder=None, is_peft_model=None, backward_batch_size=256, global_backward_batch_size=None, global_batch_size=None)
# load ref model lvwerra/gpt2-imdb
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# load train model lvwerra/gpt2-imdb
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240606_094928-y5o1idyp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run roberta16-256_0_5-gamma-2024.06.06.09.49
# wandb: ⭐️ View project at https://wandb.ai/mhayes/cs234
# wandb: 🚀 View run at https://wandb.ai/mhayes/cs234/runs/y5o1idyp
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
#   0%|                                                    | 0/97 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#   5%|██▎                                         | 5/97 [02:32<47:00, 30.66s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|███████████████████████████████████████████| 97/97 [49:52<00:00, 30.85s/it]
# model.safetensors: 100%|█████████████████████| 498M/498M [00:30<00:00, 16.4MB/s]
# Training done!  Start eval
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:28<03:48, 28.54s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:55<03:15, 27.90s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:23<02:46, 27.75s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:51<02:18, 27.64s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:18<01:50, 27.59s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:46<01:22, 27.57s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:14<00:55, 27.78s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:42<00:27, 27.77s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:10<00:00, 27.78s/it]
# mean test reward 0.5716139171891856 +/- 0.010202767907510542 from 0.4373831782098705 +/- 0.010218943991290022
# median test reward 0.9925447404384613 from 0.009207388386130333
# mean KL 0.29238916784136865 +/- 0.03160447439197268 full 0.8287039782153443 +/- 0.004859602379516957
# median KL 0.30612605810165405 full 0.7888205349445343
# roberta16-256_0_5-gamma-2024.06.06.09.49,0.5,epoch 1,0.5716139171891856,0.010202767907510542,0.8287039782153443,0.004859602379516957,15.504340277777779
