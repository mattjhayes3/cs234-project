# %%
# !conda install -y gdown
# print('hi')
# !conda install aiohttp -y
# !git clone https://github.com/mattjhayes3/cs234-project.git
# %cd /kaggle/working/cs234-project
# !git pull --rebase
# !pip install wandb
import wandb

wandb.login(key="KEY")
# wandb.init()

from huggingface_hub import notebook_login,login

# notebook_login("KEY")
login("KEY")

# !gdown --id 1TTg8s_dj60EKl4No2unSvYmMyMopPVJ6
# !gdown --id 1Z7HvAokBQu65jew4ou2DjOYRi23OrJdr
# !mkdir results
# !pip install datasets>=1.17.0 torch>=1.4.0 tqdm transformers accelerate peft>=0.3.0 tyro>=0.5.7
# !pip install git+https://github.com/mattjhayes3/trl.git
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - aiohttp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     ca-certificates-2024.6.2   |       hbcca054_0         152 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         834 KB
#
# The following packages will be UPDATED:
#
#   aiohttp                             3.9.1-py310h2372a71_0 --> 3.9.5-py310h2372a71_0
#   ca-certificates                       2024.2.2-hbcca054_0 --> 2024.6.2-hbcca054_0
#
#
#
# Downloading and Extracting Packages:
# aiohttp-3.9.5        | 682 KB    |                                       |   0%
# aiohttp-3.9.5        | 682 KB    | 8                                     |   2%
# ca-certificates-2024 | 152 KB    | #######7                              |  21%
#
#
# done
# done
# done
# Cloning into 'cs234-project'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 297 (delta 46), reused 54 (delta 24), pack-reused 220
# Receiving objects: 100% (297/297), 60.49 MiB | 19.45 MiB/s, done.
# Resolving deltas: 100% (153/153), done.
# Updating files: 100% (127/127), done.
# /kaggle/working/cs234-project
# Already up to date.
# Current branch main is up to date.
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.3.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Collecting git+https://github.com/mattjhayes3/trl.git
#   Cloning https://github.com/mattjhayes3/trl.git to /tmp/pip-req-build-ahvz4iw5
#   Running command git clone --filter=blob:none --quiet https://github.com/mattjhayes3/trl.git /tmp/pip-req-build-ahvz4iw5
#   Resolved https://github.com/mattjhayes3/trl.git to commit fce91ab1b2401a45a767d7ca6eeb940790cdd954
# done
# done
# done
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (4.41.1)
# Requirement already satisfied: numpy>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (1.26.4)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (0.30.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (2.19.1)
# Requirement already satisfied: tyro>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from trl==0.8.7.dev0) (0.8.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl==0.8.7.dev0) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->trl==0.8.7.dev0) (4.66.4)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.7.dev0) (1.7.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->trl==0.8.7.dev0) (5.9.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (2.2.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->trl==0.8.7.dev0) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (1.9.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->trl==0.8.7.dev0) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers>=4.31.0->trl==0.8.7.dev0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->trl==0.8.7.dev0) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl==0.8.7.dev0) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl==0.8.7.dev0) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl==0.8.7.dev0) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.8.7.dev0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.8.7.dev0) (1.16.0)
# Building wheels for collected packages: trl
# done
#   Created wheel for trl: filename=trl-0.8.7.dev0-py3-none-any.whl size=209807 sha256=71a8486913685db2c49e70e144e12f8e1e34a0d47b87d53df5487602db326617
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tec_j2az/wheels/b5/f5/74/f982e27bdb1c23b205f8bfcaaed174cf3d2c06bd1a5f5926cc
# Successfully built trl
# Installing collected packages: trl
# Successfully installed trl-0.8.7.dev0

# %%
# !rm -rf */*/optimizer.pt && python dpo.py --output_dir=ipo_uniform_flipped_2c2_0_25-0_2 --loss_type=ipo --beta=0.2 --dataset_name=/kaggle/working/cs234-project/pref_pairs_16_token_2_choose_2_uniform_flipped_0_25_tokenized     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128  --per_device_eval_batch_size 128     --learning_rate 2e-6     --gradient_accumulation_steps 1  --warmup_steps 150     --report_to wandb     --logging_first_step --logging_strategy='steps' --logging_steps 50  --eval_steps=150 --no_remove_unused_columns --save_total_limit=3 --evaluation_strategy='steps' --lr_scheduler_type=constant_with_warmup --save_strategy='epoch' --num_train_epochs=4
# Out:
# 2024-06-03 10:55:09.873313: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 10:55:09.873425: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 10:55:09.984193: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# config.json: 100%|█████████████████████████████| 577/577 [00:00<00:00, 3.56MB/s]
# pytorch_model.bin: 100%|█████████████████████| 548M/548M [00:10<00:00, 53.2MB/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Load model  lvwerra/gpt2-imdb
# Load ref model  lvwerra/gpt2-imdb
# tokenizer_config.json: 100%|██████████████████| 17.0/17.0 [00:00<00:00, 106kB/s]
# vocab.json: 100%|████████████████████████████| 899k/899k [00:00<00:00, 12.7MB/s]
# merges.txt: 100%|████████████████████████████| 456k/456k [00:00<00:00, 10.1MB/s]
# special_tokens_map.json: 100%|████████████████| 90.0/90.0 [00:00<00:00, 593kB/s]
# ds len 24895
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240603_105534-l091ks4f
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ipo_uniform_flipped_2c2_0_25-0_2
# wandb: ⭐️ View project at https://wandb.ai/mhayes/huggingface
# wandb: 🚀 View run at https://wandb.ai/mhayes/huggingface/runs/l091ks4f
#   0%|                                                   | 0/740 [00:00<?, ?it/s]Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 6.25, 'grad_norm': 14.65987777709961, 'learning_rate': 1.3333333333333334e-08, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/rejected': -3.9614434242248535, 'logps/chosen': -3.8425545692443848, 'logits/rejected': -35.7431755065918, 'logits/chosen': -35.82997131347656, 'epoch': 0.01}
# {'loss': 6.2487, 'grad_norm': 14.576385498046875, 'learning_rate': 6.666666666666666e-07, 'rewards/chosen': 1.3729448255617172e-05, 'rewards/rejected': -3.94520211557392e-05, 'rewards/accuracies': 0.5656887888908386, 'rewards/margins': 5.318147304933518e-05, 'logps/rejected': -3.843141794204712, 'logps/chosen': -3.8457610607147217, 'logits/rejected': -37.192527770996094, 'logits/chosen': -36.57289505004883, 'epoch': 0.27}
# {'loss': 6.2405, 'grad_norm': 14.259040832519531, 'learning_rate': 1.3333333333333332e-06, 'rewards/chosen': 8.123133011395112e-05, 'rewards/rejected': -0.00030460793641395867, 'rewards/accuracies': 0.5862500071525574, 'rewards/margins': 0.00038583925925195217, 'logps/rejected': -3.844310998916626, 'logps/chosen': -3.831620454788208, 'logits/rejected': -37.139278411865234, 'logits/chosen': -36.687679290771484, 'epoch': 0.54}
# {'loss': 6.2223, 'grad_norm': 14.949748992919922, 'learning_rate': 2e-06, 'rewards/chosen': -2.477513589838054e-05, 'rewards/rejected': -0.0011637944262474775, 'rewards/accuracies': 0.59765625, 'rewards/margins': 0.0011390192667022347, 'logps/rejected': -3.8517510890960693, 'logps/chosen': -3.8333475589752197, 'logits/rejected': -36.767608642578125, 'logits/chosen': -36.512393951416016, 'epoch': 0.81}
#  20%|████████▎                                | 150/740 [03:04<11:59,  1.22s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.65it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.23it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  1.69it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:03<00:02,  1.73it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.76it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:04<00:01,  1.78it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.80it/s]
#
# {'eval_loss': 6.216461181640625, 'eval_runtime': 5.6567, 'eval_samples_per_second': 220.091, 'eval_steps_per_second': 1.768, 'eval_rewards/chosen': -0.00012495748524088413, 'eval_rewards/rejected': -0.0015192176215350628, 'eval_rewards/accuracies': 0.5802335143089294, 'eval_rewards/margins': 0.001394260092638433, 'eval_logps/rejected': -3.895996570587158, 'eval_logps/chosen': -3.8309924602508545, 'eval_logits/rejected': -36.488670349121094, 'eval_logits/chosen': -36.1766242980957, 'epoch': 0.81}
#  20%|████████▎                                | 150/740 [03:10<11:59,  1.22s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  2.00it/s]
# {'loss': 6.1808, 'grad_norm': 14.918898582458496, 'learning_rate': 2e-06, 'rewards/chosen': -0.0004992520553059876, 'rewards/rejected': -0.0033723486121743917, 'rewards/accuracies': 0.6254879236221313, 'rewards/margins': 0.0028730963822454214, 'logps/rejected': -3.8726143836975098, 'logps/chosen': -3.816112995147705, 'logits/rejected': -37.16756820678711, 'logits/chosen': -36.55402755737305, 'epoch': 1.08}
# {'loss': 6.1277, 'grad_norm': 14.587879180908203, 'learning_rate': 2e-06, 'rewards/chosen': -0.001453713164664805, 'rewards/rejected': -0.006584791466593742, 'rewards/accuracies': 0.6418750286102295, 'rewards/margins': 0.005131078884005547, 'logps/rejected': -3.87111234664917, 'logps/chosen': -3.8317525386810303, 'logits/rejected': -36.65548324584961, 'logits/chosen': -36.35905838012695, 'epoch': 1.35}
# {'loss': 6.1016, 'grad_norm': 15.173038482666016, 'learning_rate': 2e-06, 'rewards/chosen': -0.0038787040393799543, 'rewards/rejected': -0.010253463871777058, 'rewards/accuracies': 0.6384375095367432, 'rewards/margins': 0.006374759133905172, 'logps/rejected': -3.8825974464416504, 'logps/chosen': -3.8474249839782715, 'logits/rejected': -36.46076583862305, 'logits/chosen': -36.08218765258789, 'epoch': 1.62}
#  41%|████████████████▌                        | 300/740 [06:16<09:08,  1.25s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.66it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.23it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  1.77it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:02<00:02,  1.79it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.80it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:04<00:01,  1.81it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.82it/s]
#
# {'eval_loss': 6.159539699554443, 'eval_runtime': 5.5833, 'eval_samples_per_second': 222.988, 'eval_steps_per_second': 1.791, 'eval_rewards/chosen': -0.005756011698395014, 'eval_rewards/rejected': -0.00990608986467123, 'eval_rewards/accuracies': 0.5772093534469604, 'eval_rewards/margins': 0.004150078631937504, 'eval_logps/rejected': -3.9379305839538574, 'eval_logps/chosen': -3.859147548675537, 'eval_logits/rejected': -35.92123794555664, 'eval_logits/chosen': -35.6425895690918, 'epoch': 1.62}
#  41%|████████████████▌                        | 300/740 [06:22<09:08,  1.25s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:04<00:00,  2.01it/s]
# {'loss': 6.0837, 'grad_norm': 15.221319198608398, 'learning_rate': 2e-06, 'rewards/chosen': -0.0066183628514409065, 'rewards/rejected': -0.013903501443564892, 'rewards/accuracies': 0.6267187595367432, 'rewards/margins': 0.007285137195140123, 'logps/rejected': -3.9086639881134033, 'logps/chosen': -3.8839752674102783, 'logits/rejected': -36.3142204284668, 'logits/chosen': -35.750370025634766, 'epoch': 1.89}
# {'loss': 6.0035, 'grad_norm': 13.735881805419922, 'learning_rate': 2e-06, 'rewards/chosen': -0.009192712604999542, 'rewards/rejected': -0.019947927445173264, 'rewards/accuracies': 0.6568846106529236, 'rewards/margins': 0.010755213908851147, 'logps/rejected': -3.9577701091766357, 'logps/chosen': -3.872013807296753, 'logits/rejected': -36.420814514160156, 'logits/chosen': -36.035682678222656, 'epoch': 2.16}
# {'loss': 5.9549, 'grad_norm': 14.765968322753906, 'learning_rate': 2e-06, 'rewards/chosen': -0.01257179956883192, 'rewards/rejected': -0.02571740187704563, 'rewards/accuracies': 0.6654687523841858, 'rewards/margins': 0.013145599514245987, 'logps/rejected': -3.9827840328216553, 'logps/chosen': -3.8929076194763184, 'logits/rejected': -36.310001373291016, 'logits/chosen': -36.10328674316406, 'epoch': 2.43}
#  61%|████████████████████████▉                | 450/740 [09:27<06:00,  1.24s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.65it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.23it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  1.71it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:03<00:02,  1.74it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.77it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:04<00:01,  1.79it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.81it/s]
#
# {'eval_loss': 6.112009525299072, 'eval_runtime': 5.6396, 'eval_samples_per_second': 220.762, 'eval_steps_per_second': 1.773, 'eval_rewards/chosen': -0.01742783561348915, 'eval_rewards/rejected': -0.024420548230409622, 'eval_rewards/accuracies': 0.5791582465171814, 'eval_rewards/margins': 0.006992711685597897, 'eval_logps/rejected': -4.01050329208374, 'eval_logps/chosen': -3.917506694793701, 'eval_logits/rejected': -35.91708755493164, 'eval_logits/chosen': -35.68437957763672, 'epoch': 2.43}
#  61%|████████████████████████▉                | 450/740 [09:32<06:00,  1.24s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  2.00it/s]
# {'loss': 5.9369, 'grad_norm': 14.099649429321289, 'learning_rate': 2e-06, 'rewards/chosen': -0.017149722203612328, 'rewards/rejected': -0.03143128752708435, 'rewards/accuracies': 0.6514062285423279, 'rewards/margins': 0.014281566254794598, 'logps/rejected': -3.9959022998809814, 'logps/chosen': -3.9281859397888184, 'logits/rejected': -36.287109375, 'logits/chosen': -35.932212829589844, 'epoch': 2.7}
# {'loss': 5.8979, 'grad_norm': 14.098538398742676, 'learning_rate': 2e-06, 'rewards/chosen': -0.021629109978675842, 'rewards/rejected': -0.037940870970487595, 'rewards/accuracies': 0.6521875262260437, 'rewards/margins': 0.0163117628544569, 'logps/rejected': -4.033472061157227, 'logps/chosen': -3.9352059364318848, 'logits/rejected': -36.17155838012695, 'logits/chosen': -35.783935546875, 'epoch': 2.97}
# {'loss': 5.8034, 'grad_norm': 15.631073951721191, 'learning_rate': 2e-06, 'rewards/chosen': -0.026564743369817734, 'rewards/rejected': -0.047351617366075516, 'rewards/accuracies': 0.6711384057998657, 'rewards/margins': 0.02078687585890293, 'logps/rejected': -4.077795505523682, 'logps/chosen': -3.957670211791992, 'logits/rejected': -36.13076400756836, 'logits/chosen': -35.83274459838867, 'epoch': 3.24}
#  81%|█████████████████████████████████▏       | 600/740 [12:39<02:56,  1.26s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.65it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.24it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  2.03it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:02<00:02,  1.95it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.91it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:03<00:01,  1.88it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.88it/s]
#
# {'eval_loss': 6.061832904815674, 'eval_runtime': 5.3692, 'eval_samples_per_second': 231.878, 'eval_steps_per_second': 1.862, 'eval_rewards/chosen': -0.03408427909016609, 'eval_rewards/rejected': -0.044597309082746506, 'eval_rewards/accuracies': 0.5768145322799683, 'eval_rewards/margins': 0.010513030923902988, 'eval_logps/rejected': -4.111386299133301, 'eval_logps/chosen': -4.000789642333984, 'eval_logits/rejected': -35.9738655090332, 'eval_logits/chosen': -35.809043884277344, 'epoch': 3.24}
#  81%|█████████████████████████████████▏       | 600/740 [12:44<02:56,  1.26s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:04<00:00,  2.06it/s]
# {'loss': 5.7959, 'grad_norm': 13.942925453186035, 'learning_rate': 2e-06, 'rewards/chosen': -0.033685263246297836, 'rewards/rejected': -0.055353011935949326, 'rewards/accuracies': 0.6631249785423279, 'rewards/margins': 0.02166774682700634, 'logps/rejected': -4.135246276855469, 'logps/chosen': -4.006769180297852, 'logits/rejected': -36.269100189208984, 'logits/chosen': -36.105655670166016, 'epoch': 3.51}
# {'loss': 5.7718, 'grad_norm': 14.605533599853516, 'learning_rate': 2e-06, 'rewards/chosen': -0.03975079581141472, 'rewards/rejected': -0.06308602541685104, 'rewards/accuracies': 0.65234375, 'rewards/margins': 0.023335233330726624, 'logps/rejected': -4.150489330291748, 'logps/chosen': -4.035376071929932, 'logits/rejected': -36.603572845458984, 'logits/chosen': -36.2960205078125, 'epoch': 3.78}
# {'train_runtime': 955.3471, 'train_samples_per_second': 99.022, 'train_steps_per_second': 0.775, 'train_loss': 6.011474382555162, 'epoch': 4.0}
# 100%|█████████████████████████████████████████| 740/740 [15:38<00:00,  1.27s/it]
# Evaling epochs [4, 3, 2]
# Loading from ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55/checkpoint-740
# Downloading readme: 100%|██████████████████| 7.81k/7.81k [00:00<00:00, 16.1MB/s]
# Downloading data: 100%|████████████████████| 21.0M/21.0M [00:00<00:00, 71.3MB/s]
# Downloading data: 100%|█████████████████████| 20.5M/20.5M [00:00<00:00, 123MB/s]
# Downloading data: 100%|█████████████████████| 42.0M/42.0M [00:00<00:00, 164MB/s]
# Generating train split: 100%|██| 25000/25000 [00:00<00:00, 149796.36 examples/s]
# Generating test split: 100%|███| 25000/25000 [00:00<00:00, 176788.96 examples/s]
# Generating unsupervised split: 100%|█| 50000/50000 [00:00<00:00, 176939.61 examp
# Filter: 100%|███████████████████████| 250/250 [00:00<00:00, 46522.74 examples/s]
# Map:   0%|                                       | 0/250 [00:00<?, ? examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors
# Map: 100%|████████████████████████████| 250/250 [00:00<00:00, 837.41 examples/s]
# load ref model lvwerra/gpt2-imdb
# load train model ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55/checkpoint-740
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# config.json: 100%|█████████████████████████████| 687/687 [00:00<00:00, 2.85MB/s]
# pytorch_model.bin: 100%|████████████████████| 1.42G/1.42G [00:04<00:00, 290MB/s]
# tokenizer_config.json: 100%|████████████████████| 256/256 [00:00<00:00, 750kB/s]
# vocab.json: 100%|████████████████████████████| 798k/798k [00:00<00:00, 17.1MB/s]
# merges.txt: 100%|████████████████████████████| 456k/456k [00:00<00:00, 9.53MB/s]
# special_tokens_map.json: 100%|██████████████████| 150/150 [00:00<00:00, 483kB/s]
# eval batch size 256
# Filter: 100%|████████████████████| 2500/2500 [00:00<00:00, 135931.55 examples/s]
# Map:   3%|▉                           | 81/2487 [00:00<00:03, 793.02 examples/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1300 > 1024). Running this sequence through the model will result in indexing errors
# Map: 100%|██████████████████████████| 2487/2487 [00:08<00:00, 301.89 examples/s]
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:33, 26.68s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:53<03:06, 26.64s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:20<02:40, 26.73s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:47<02:14, 26.81s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:13<01:47, 26.80s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#  67%|██████████████████████████████               | 6/9 [02:40<01:20, 26.74s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:07<00:53, 26.76s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:33<00:26, 26.74s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:00<00:00, 26.75s/it]
# mean test reward 0.8264793682068456 +/- 0.007790543392902146 from 0.4351168664733096 +/- 0.010216795621720676
# median test reward 0.9986612200737 from 0.00922983093187213
# mean KL 1.9765573335397575 +/- 0.08225700118525676 full 4.5851519093848765 +/- 0.034659366446109355
# median KL 2.4007619619369507 full 4.374248504638672
# Loading from ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55/checkpoint-555
# load ref model lvwerra/gpt2-imdb
# load train model ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55/checkpoint-555
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:32, 26.52s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:53<03:06, 26.62s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:19<02:40, 26.68s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:46<02:13, 26.69s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:13<01:46, 26.74s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:40<01:20, 26.77s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:07<00:53, 26.84s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:34<00:27, 27.02s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:01<00:00, 26.83s/it]
# mean test reward 0.7793149447425852 +/- 0.008548569588811665 from 0.4351168664733096 +/- 0.010216795621720676
# median test reward 0.9983974695205688 from 0.00922983093187213
# mean KL 1.2906363839865662 +/- 0.06065483884211106 full 2.810521654681199 +/- 0.023826852214516525
# median KL 1.520814299583435 full 2.6308774948120117
# Loading from ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55/checkpoint-370
# load ref model lvwerra/gpt2-imdb
# load train model ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55/checkpoint-370
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:32, 26.62s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:53<03:07, 26.76s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:20<02:40, 26.83s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:47<02:14, 26.84s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:14<01:47, 26.88s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:40<01:20, 26.83s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:07<00:53, 26.85s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:34<00:26, 26.81s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:01<00:00, 26.83s/it]
# mean test reward 0.6788096858577369 +/- 0.009625897602650339 from 0.4351168664733096 +/- 0.010216795621720676
# median test reward 0.9970945119857788 from 0.00922983093187213
# mean KL 0.3824102039798163 +/- 0.03804910998049956 full 1.1856756213819608 +/- 0.011508613647362996
# median KL 0.5493931770324707 full 1.0956294536590576
# ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55,0.2,epoch 4,0.8264793682068456,0.007790543392902146,4.5851519093848765,0.034659366446109355
# ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55,0.2,epoch 3,0.7793149447425852,0.008548569588811665,2.810521654681199,0.023826852214516525
# ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.10.55,0.2,epoch 2,0.6788096858577369,0.009625897602650339,1.1856756213819608,0.011508613647362996

# %%
# !rm -rf */*/optimizer.pt && python dpo.py --output_dir=ipo_uniform_flipped_2c2_0_25-0_2 --loss_type=ipo --beta=0.05 --dataset_name=/kaggle/working/cs234-project/pref_pairs_16_token_2_choose_2_uniform_flipped_0_25_tokenized     --model_name_or_path=lvwerra/gpt2-imdb     --per_device_train_batch_size 128  --per_device_eval_batch_size 128     --learning_rate 2e-6     --gradient_accumulation_steps 1  --warmup_steps 150     --report_to wandb     --logging_first_step --logging_strategy='steps' --logging_steps 50  --eval_steps=150 --no_remove_unused_columns --save_total_limit=3 --evaluation_strategy='steps' --lr_scheduler_type=constant_with_warmup --save_strategy='epoch' --num_train_epochs=4
# Out:
# 2024-06-03 11:24:23.848590: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 11:24:23.848661: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 11:24:23.850194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Load model  lvwerra/gpt2-imdb
# Load ref model  lvwerra/gpt2-imdb
# ds len 24895
# wandb: Currently logged in as: mjh388 (mhayes). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/cs234-project/wandb/run-20240603_112430-33ty295z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ipo_uniform_flipped_2c2_0_25-0_2
# wandb: ⭐️ View project at https://wandb.ai/mhayes/huggingface
# wandb: 🚀 View run at https://wandb.ai/mhayes/huggingface/runs/33ty295z
#   0%|                                                   | 0/740 [00:00<?, ?it/s]Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 100.0, 'grad_norm': 58.63951110839844, 'learning_rate': 1.3333333333333334e-08, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/rejected': -3.9614434242248535, 'logps/chosen': -3.8425545692443848, 'logits/rejected': -35.7431755065918, 'logits/chosen': -35.82997131347656, 'epoch': 0.01}
# {'loss': 99.9947, 'grad_norm': 58.31390380859375, 'learning_rate': 6.666666666666666e-07, 'rewards/chosen': 3.4233185033372138e-06, 'rewards/rejected': -9.879028766590636e-06, 'rewards/accuracies': 0.5644132494926453, 'rewards/margins': 1.3302347724675201e-05, 'logps/rejected': -3.843142032623291, 'logps/chosen': -3.8457610607147217, 'logits/rejected': -37.19249725341797, 'logits/chosen': -36.5728645324707, 'epoch': 0.27}
# {'loss': 99.9613, 'grad_norm': 57.09324645996094, 'learning_rate': 1.3333333333333332e-06, 'rewards/chosen': 2.0091329133720137e-05, 'rewards/rejected': -7.685133459744975e-05, 'rewards/accuracies': 0.5864062309265137, 'rewards/margins': 9.694265463622287e-05, 'logps/rejected': -3.8443245887756348, 'logps/chosen': -3.831624746322632, 'logits/rejected': -37.13850402832031, 'logits/chosen': -36.686912536621094, 'epoch': 0.54}
# {'loss': 99.8857, 'grad_norm': 59.93891143798828, 'learning_rate': 2e-06, 'rewards/chosen': -1.1628444553934969e-05, 'rewards/rejected': -0.00029941339744254947, 'rewards/accuracies': 0.5978124737739563, 'rewards/margins': 0.0002877849037759006, 'logps/rejected': -3.8519201278686523, 'logps/chosen': -3.833456039428711, 'logits/rejected': -36.76041030883789, 'logits/chosen': -36.505340576171875, 'epoch': 0.81}
#  20%|████████▎                                | 150/740 [03:04<12:00,  1.22s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.64it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.22it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  1.70it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:03<00:02,  1.74it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.77it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:04<00:01,  1.78it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.81it/s]
#
# {'eval_loss': 99.85984802246094, 'eval_runtime': 5.6431, 'eval_samples_per_second': 220.623, 'eval_steps_per_second': 1.772, 'eval_rewards/chosen': -4.22564844484441e-05, 'eval_rewards/rejected': -0.00039606154314242303, 'eval_rewards/accuracies': 0.5805275440216064, 'eval_rewards/margins': 0.00035380502231419086, 'eval_logps/rejected': -3.8963215351104736, 'eval_logps/chosen': -3.8312129974365234, 'eval_logits/rejected': -36.47439956665039, 'eval_logits/chosen': -36.162330627441406, 'epoch': 0.81}
#  20%|████████▎                                | 150/740 [03:10<12:00,  1.22s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:05<00:00,  2.00it/s]
# {'loss': 99.7087, 'grad_norm': 59.86464309692383, 'learning_rate': 2e-06, 'rewards/chosen': -0.00015018855629023165, 'rewards/rejected': -0.0008853296167217195, 'rewards/accuracies': 0.6231441497802734, 'rewards/margins': 0.0007351410458795726, 'logps/rejected': -3.873459577560425, 'logps/chosen': -3.8166205883026123, 'logits/rejected': -37.14655685424805, 'logits/chosen': -36.533470153808594, 'epoch': 1.08}
# {'loss': 99.4774, 'grad_norm': 59.21516418457031, 'learning_rate': 2e-06, 'rewards/chosen': -0.00045174488332122564, 'rewards/rejected': -0.0017749540274962783, 'rewards/accuracies': 0.6404687762260437, 'rewards/margins': 0.0013232091441750526, 'logps/rejected': -3.873687744140625, 'logps/chosen': -3.833519220352173, 'logits/rejected': -36.61788558959961, 'logits/chosen': -36.323150634765625, 'epoch': 1.35}
# {'loss': 99.3466, 'grad_norm': 61.08908462524414, 'learning_rate': 2e-06, 'rewards/chosen': -0.0012018601410090923, 'rewards/rejected': -0.002867175731807947, 'rewards/accuracies': 0.6342187523841858, 'rewards/margins': 0.0016653153579682112, 'logps/rejected': -3.888673782348633, 'logps/chosen': -3.8520684242248535, 'logits/rejected': -36.39480972290039, 'logits/chosen': -36.020362854003906, 'epoch': 1.62}
#  41%|████████████████▌                        | 300/740 [06:15<09:02,  1.23s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.66it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.24it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  1.77it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:02<00:02,  1.79it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.80it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:04<00:01,  1.81it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.82it/s]
#
# {'eval_loss': 99.57241821289062, 'eval_runtime': 5.5764, 'eval_samples_per_second': 223.261, 'eval_steps_per_second': 1.793, 'eval_rewards/chosen': -0.0017687216168269515, 'eval_rewards/rejected': -0.002879542298614979, 'eval_rewards/accuracies': 0.5748655796051025, 'eval_rewards/margins': 0.0011108206817880273, 'eval_logps/rejected': -3.945990800857544, 'eval_logps/chosen': -3.8657422065734863, 'eval_logits/rejected': -35.83793640136719, 'eval_logits/chosen': -35.56194305419922, 'epoch': 1.62}
#  41%|████████████████▌                        | 300/740 [06:21<09:02,  1.23s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:04<00:00,  2.01it/s]
# {'loss': 99.2438, 'grad_norm': 61.255313873291016, 'learning_rate': 2e-06, 'rewards/chosen': -0.0021211353596299887, 'rewards/rejected': -0.004060184583067894, 'rewards/accuracies': 0.6225000023841858, 'rewards/margins': 0.0019390491070225835, 'logps/rejected': -3.9203500747680664, 'logps/chosen': -3.893306255340576, 'logits/rejected': -36.212425231933594, 'logits/chosen': -35.653072357177734, 'epoch': 1.89}
# {'loss': 98.8677, 'grad_norm': 56.63407897949219, 'learning_rate': 2e-06, 'rewards/chosen': -0.003129286225885153, 'rewards/rejected': -0.0060325427912175655, 'rewards/accuracies': 0.6481345891952515, 'rewards/margins': 0.002903256332501769, 'logps/rejected': -3.9786813259124756, 'logps/chosen': -3.8886358737945557, 'logits/rejected': -36.27074432373047, 'logits/chosen': -35.89860534667969, 'epoch': 2.16}
# {'loss': 98.6085, 'grad_norm': 60.3211555480957, 'learning_rate': 2e-06, 'rewards/chosen': -0.0045558311976492405, 'rewards/rejected': -0.00815030187368393, 'rewards/accuracies': 0.6521875262260437, 'rewards/margins': 0.0035944702103734016, 'logps/rejected': -4.017202854156494, 'logps/chosen': -3.9211654663085938, 'logits/rejected': -36.138301849365234, 'logits/chosen': -35.940216064453125, 'epoch': 2.43}
#  61%|████████████████████████▉                | 450/740 [09:27<06:02,  1.25s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.65it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.24it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  1.77it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:02<00:02,  1.78it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.80it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:04<00:01,  1.81it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.82it/s]
#
# {'eval_loss': 99.243408203125, 'eval_runtime': 5.574, 'eval_samples_per_second': 223.359, 'eval_steps_per_second': 1.794, 'eval_rewards/chosen': -0.0061715939082205296, 'eval_rewards/rejected': -0.00819936953485012, 'eval_rewards/accuracies': 0.5747647881507874, 'eval_rewards/margins': 0.0020277765579521656, 'eval_logps/rejected': -4.0523881912231445, 'eval_logps/chosen': -3.9537997245788574, 'eval_logits/rejected': -35.716697692871094, 'eval_logits/chosen': -35.4970703125, 'epoch': 2.43}
#  61%|████████████████████████▉                | 450/740 [09:33<06:02,  1.25s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:04<00:00,  2.02it/s]
# {'loss': 98.4667, 'grad_norm': 58.54132843017578, 'learning_rate': 2e-06, 'rewards/chosen': -0.006525783333927393, 'rewards/rejected': -0.010520818643271923, 'rewards/accuracies': 0.6356250047683716, 'rewards/margins': 0.00399503530934453, 'logps/rejected': -4.0491623878479, 'logps/chosen': -3.9729528427124023, 'logits/rejected': -36.071998596191406, 'logits/chosen': -35.731685638427734, 'epoch': 2.7}
# {'loss': 98.1861, 'grad_norm': 58.729705810546875, 'learning_rate': 2e-06, 'rewards/chosen': -0.008745698258280754, 'rewards/rejected': -0.013500257395207882, 'rewards/accuracies': 0.6404687762260437, 'rewards/margins': 0.0047545600682497025, 'logps/rejected': -4.113773345947266, 'logps/chosen': -4.001974582672119, 'logits/rejected': -35.9439582824707, 'logits/chosen': -35.60171890258789, 'epoch': 2.97}
# {'loss': 97.6837, 'grad_norm': 66.70639038085938, 'learning_rate': 2e-06, 'rewards/chosen': -0.0116024324670434, 'rewards/rejected': -0.017703678458929062, 'rewards/accuracies': 0.653734028339386, 'rewards/margins': 0.006101246923208237, 'logps/rejected': -4.195111274719238, 'logps/chosen': -4.0568952560424805, 'logits/rejected': -35.9640007019043, 'logits/chosen': -35.69904327392578, 'epoch': 3.24}
#  81%|█████████████████████████████████▏       | 600/740 [12:40<02:55,  1.25s/it]evaluation_loop
#
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  20%|████████▊                                   | 2/10 [00:00<00:02,  3.66it/s]
#  30%|█████████████▏                              | 3/10 [00:01<00:02,  2.58it/s]
#  40%|█████████████████▌                          | 4/10 [00:01<00:02,  2.21it/s]
#  50%|██████████████████████                      | 5/10 [00:02<00:02,  2.02it/s]
#  60%|██████████████████████████▍                 | 6/10 [00:02<00:02,  1.95it/s]
#  70%|██████████████████████████████▊             | 7/10 [00:03<00:01,  1.91it/s]
#  80%|███████████████████████████████████▏        | 8/10 [00:03<00:01,  1.88it/s]
#  90%|███████████████████████████████████████▌    | 9/10 [00:04<00:00,  1.87it/s]
#
# {'eval_loss': 98.78048706054688, 'eval_runtime': 5.3804, 'eval_samples_per_second': 231.393, 'eval_steps_per_second': 1.859, 'eval_rewards/chosen': -0.014563809148967266, 'eval_rewards/rejected': -0.017957128584384918, 'eval_rewards/accuracies': 0.5817960500717163, 'eval_rewards/margins': 0.003393322927877307, 'eval_logps/rejected': -4.247542858123779, 'eval_logps/chosen': -4.121644020080566, 'eval_logits/rejected': -35.817893981933594, 'eval_logits/chosen': -35.702537536621094, 'epoch': 3.24}
#  81%|█████████████████████████████████▏       | 600/740 [12:45<02:55,  1.25s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:04<00:00,  2.05it/s]
# {'loss': 97.5268, 'grad_norm': 59.656375885009766, 'learning_rate': 2e-06, 'rewards/chosen': -0.01560754980891943, 'rewards/rejected': -0.022201936691999435, 'rewards/accuracies': 0.6443750262260437, 'rewards/margins': 0.006594388280063868, 'logps/rejected': -4.302520275115967, 'logps/chosen': -4.150493621826172, 'logits/rejected': -36.181480407714844, 'logits/chosen': -36.073123931884766, 'epoch': 3.51}
# {'loss': 97.2998, 'grad_norm': 60.7559700012207, 'learning_rate': 2e-06, 'rewards/chosen': -0.01984454318881035, 'rewards/rejected': -0.027127446606755257, 'rewards/accuracies': 0.6328125, 'rewards/margins': 0.007282900623977184, 'logps/rejected': -4.377607822418213, 'logps/chosen': -4.233513355255127, 'logits/rejected': -36.633148193359375, 'logits/chosen': -36.40807342529297, 'epoch': 3.78}
# {'train_runtime': 957.1099, 'train_samples_per_second': 98.839, 'train_steps_per_second': 0.773, 'train_loss': 98.78003886454815, 'epoch': 4.0}
# 100%|█████████████████████████████████████████| 740/740 [15:40<00:00,  1.27s/it]
# Evaling epochs [4, 3, 2]
# Loading from ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24/checkpoint-740
# load ref model lvwerra/gpt2-imdb
# load train model ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24/checkpoint-740
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:31, 26.47s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:53<03:06, 26.68s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:19<02:39, 26.61s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:46<02:12, 26.60s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:13<01:46, 26.60s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#  67%|██████████████████████████████               | 6/9 [02:39<01:19, 26.56s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:06<00:53, 26.67s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:34<00:27, 27.08s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:01<00:00, 26.87s/it]
# mean test reward 0.8630647430655043 +/- 0.007082179613714393 from 0.4351168664733096 +/- 0.010216795621720676
# median test reward 0.9987814426422119 from 0.00922983093187213
# mean KL 4.287940610898659 +/- 0.11933159630477048 full 8.49234432540834 +/- 0.054147205684147444
# median KL 4.851257562637329 full 8.217524528503418
# Loading from ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24/checkpoint-555
# load ref model lvwerra/gpt2-imdb
# load train model ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24/checkpoint-555
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:27<03:37, 27.14s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:54<03:10, 27.21s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:21<02:42, 27.00s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:48<02:14, 26.95s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:14<01:47, 26.88s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:41<01:20, 26.85s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:08<00:53, 26.76s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:34<00:26, 26.78s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:01<00:00, 26.86s/it]
# mean test reward 0.8128123041297562 +/- 0.008033245244098477 from 0.4351168664733096 +/- 0.010216795621720676
# median test reward 0.9986088573932648 from 0.00922983093187213
# mean KL 1.989624428388197 +/- 0.07585716514473413 full 4.170346149786686 +/- 0.03264702814674888
# median KL 2.2817444801330566 full 3.9555212259292603
# Loading from ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24/checkpoint-370
# load ref model lvwerra/gpt2-imdb
# load train model ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24/checkpoint-370
# device cuda
# device 0
# Load reward model siebert/sentiment-roberta-large-english
# eval batch size 256
# test len 9
#   0%|                                                     | 0/9 [00:00<?, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  11%|█████                                        | 1/9 [00:26<03:33, 26.74s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  22%|██████████                                   | 2/9 [00:53<03:07, 26.80s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  33%|███████████████                              | 3/9 [01:20<02:40, 26.77s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  44%|████████████████████                         | 4/9 [01:47<02:14, 26.92s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  56%|█████████████████████████                    | 5/9 [02:14<01:47, 27.00s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  67%|██████████████████████████████               | 6/9 [02:41<01:21, 27.01s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  78%|███████████████████████████████████          | 7/9 [03:08<00:53, 26.96s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#  89%|████████████████████████████████████████     | 8/9 [03:35<00:26, 26.96s/it]/opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# 100%|█████████████████████████████████████████████| 9/9 [04:02<00:00, 26.95s/it]
# mean test reward 0.6997948472956826 +/- 0.009450987644784402 from 0.4351168664733096 +/- 0.010216795621720676
# median test reward 0.9975670278072357 from 0.00922983093187213
# mean KL 0.45893480349978844 +/- 0.042520264646857174 full 1.4738161093911104 +/- 0.013628959169348863
# median KL 0.6189583539962769 full 1.3706688284873962
# ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24,0.05,epoch 4,0.8630647430655043,0.007082179613714393,8.49234432540834,0.054147205684147444
# ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24,0.05,epoch 3,0.8128123041297562,0.008033245244098477,4.170346149786686,0.03264702814674888
# ipo_uniform_flipped_2c2_0_25-0_2-2024.06.03.11.24,0.05,epoch 2,0.6997948472956826,0.009450987644784402,1.4738161093911104,0.013628959169348863
